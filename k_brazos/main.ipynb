# %% [markdown]
# <a href="https://colab.research.google.com/github/YagoIbarrola/EML_Carrillo_Ibarrola_Palomar/blob/main/k_brazos/main.ipynb" target="_parent">
# <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
#@title Copiar el repositorio.
print("Clonando el repositorio, tiempo estimado: 1-2 minutos...")
# !git clone https://github.com/YagoIbarrola/EML_Carrillo_Ibarrola_Palomar.git
# !cd EML_Carrillo_Ibarrola_Palomar/

#@title Importamos todas las clases y funciones
import sys
# Añadir los directorio fuentes al path de Python
sys.path.append('/content/EML_Carrillo_Ibarrola_Palomar')
# Verificar que se han añadido correctamente
print(sys.path)

# %% [markdown]
# # Problema del Bandido de k-Brazos
# ## Máster en Inteligencia Artificial – Aprendizaje por Refuerzo
#
# ## Autores
# - Carrillo Ibáñez, Ginés
# - Ibarrola Lapeña, Yago
# - Palomar Peña, Aarón
#
# ## Descripción
#
# Este proyecto desarrolla un estudio experimental del problema del **bandido de k-brazos en entornos estacionarios**, comparando distintas familias de algoritmos:
#
# - Métodos Greedy: $\epsilon$-greedy, $\epsilon$-decaimiento
# - Métodos UCB: UCB1, UCB2
# - Métodos de Gradiente: Softmax
#
# Se evalúan bajo distintos tipos de brazos:
# - Distribución Bernoulli
# - Distribución Binomial
# - Distribución Normal
#
# El objetivo es analizar empíricamente:
# - Recompensa promedio
# - Porcentaje de selección del brazo óptimo
# - Estadísticas por brazo
# - Regret acumulado

# %% [markdown]
# # Organización
#
# Los estudios experimentales están divididos en notebooks independientes:
#
# ## Experimento Base Bandit
# - [Abrir bandit_experiment.ipynb](bandit_experiment.ipynb)
#
# ## Estudio familia $\epsilon$-Greedy
# - [Abrir notebook $\epsilon$-Greedy](epsilon_greedy.ipynb)
#
# ## Estudio familia UCB
# - [Abrir notebook UCB](ucb.ipynb)
#
# ## Estudio Softmax
# - [Abrir notebook Softmax](softmax_experiment.ipynb)
#
# ## Comparación Global
# - [Abrir comparation_experiment.ipynb](comparation_experiment.ipynb)
