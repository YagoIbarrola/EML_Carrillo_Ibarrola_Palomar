# %% [markdown]
# # Problema entonos complejos
# ## Máster en Inteligencia Artificial – Aprendizaje por Refuerzo
#
# ## Autores
# - Carrillo Ibáñez, Ginés
# - Ibarrola Lapeña, Yago
# - Palomar Peña, Aarón
#
# ## Descripción
#
# Este proyecto desarrolla un estudio experimental del problema del **bandido de k-brazos en entornos estacionarios**, comparando distintas familias de algoritmos:
#
# - Métodos Greedy: $\epsilon$-greedy, $\epsilon$-decaimiento
# - Métodos UCB: UCB1, UCB2
# - Métodos de Gradiente: Softmax
#
# Se evalúan bajo distintos tipos de brazos:
# - Distribución Bernoulli
# - Distribución Binomial
# - Distribución Normal
#
# El objetivo es analizar empíricamente:
# - Recompensa promedio
# - Porcentaje de selección del brazo óptimo
# - Estadísticas por brazo
# - Regret acumulado

# %% [markdown]
# # Organización
#
# Los estudios experimentales están divididos en notebooks independientes:
#
# ## Experimento FrozenLake Monte Carlo
# - [Abrir MonteCarloTodasLasVisitas.ipynb](MonteCarloTodasLasVisitas.ipynb)
#
# ## Experimento Taxi-v3 Monte Carlo
# - [Abrir taxi_montecarlo.ipynb](taxi_montecarlo.ipynb)
#
# ## Experimento Taxi-v3 SARSA
# - [Abrir notebook taxi_SARSA](taxi_SARSA.ipynb)
#
# ## Experimento Taxi-v3 Q-Learning
# - [Abrir notebook taxi_QLearning](taxi_QLearning.ipynb)
#
# ## Experimento Lunar Lander SARSA con tiling
# - [Abrir notebook lunar_SARSASemi](lunar_SARSASemi.ipynb)
#
# ## Experimento Lunar Lander SARSA con red neuronal
# - [Abrir notebook lunar_SARSA_QNet_copy](lunar_SARSA_QNet_copy.ipynb)
#
# ## Experimento Lunar Lander Deep Q-Learning
# - [Abrir notebook lunarlander_deepqlearning](lunarlander_deepqlearning.ipynb)
