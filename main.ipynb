# %% [markdown]
# <a href="https://colab.research.google.com/github/YagoIbarrola/EML_Carrillo_Ibarrola_Palomar/blob/main.ipynb" target="_parent">
# <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# Clonar repositorio
# !git clone https://github.com/YagoIbarrola/EML_Carrillo_Ibarrola_Palomar.git

# %%
# %cd EML_Carrillo_Ibarrola_Palomar

# %%
# !pip install -r requirements.txt

# %%
import sys
sys.path.append('/content/EML_Carrillo_Ibarrola_Palomar/k_brazos/src')
sys.path.append('/content/EML_Carrillo_Ibarrola_Palomar/Entornos_Complejos/agents')
sys.path.append('/content/EML_Carrillo_Ibarrola_Palomar/Entornos_Complejos/')

# %% [markdown]
# # Experimentos K-Armed Bandit
# - [Parte 1: Bandido de k-brazos](k_brazos/main.ipynb)
#
# # Experimentos Entornos Complejos
# - [Parte 2: Entornos complejos](Entornos_Complejos/main.ipynb)

# %% [markdown]
# En el resto:
# <a href="https://colab.research.google.com/github/ldaniel-hm/eml_k_bandit/blob/main/notebooks/part1_bandit.ipynb" target="_parent">
# <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
# import sys
# sys.path.append('/content/eml_k_bandit/src')
